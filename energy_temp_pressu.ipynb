# %% [markdown]
# ### Umbrella Sampling Energy, Temp Graph

# %%
# Import dependencies
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import os

# %% [markdown]
# ### Potential Energy

# %%
# Set the file path to the Excel file containing the stress-strain data.
data_file = r'Z:/UW_Madison_Jiahui/projects/PA_Membrane/mem_moy/subhamoy_swiss_itp/nacl_0.6Molar/S1_EneMin/min-energy.xvg'

# Load data from the specified text file into a NumPy array.
# The 'comments' parameter tells the function to ignore lines that start with these characters.
data_array = np.loadtxt(data_file, comments=('#', '@'))

# Print the shape of the array.
print("Data shape:", data_array.shape)
# Out:
# Data shape: (1387, 2)

# %%
# Extract the first column as the x-axis data.
x = data_array[:, 0]

# Extract the second column as the y-axis data.
y = data_array[:, 1]

# Create a figure for the plot with a specific size.
plt.figure(figsize=(10, 6))

# Plot the x and y data.
plt.plot(x, y, label='Potential Energy', color='red')

# Add labels for the x and y axes.
plt.xlabel("Time (ps)")
plt.ylabel("Potential Energy (kJ/mol)")

# Add a title to the plot.
# plt.title("GROMACS Energies")

# Display the legend.
plt.legend()

# Display the plot.
plt.show()

# %% [markdown]
# ### Temperature

# %%
# Set the file path to the Excel file containing the stress-strain data.
data_file = r'Z:/UW_Madison_Jiahui/projects/PA_Membrane/mem_moy/subhamoy_swiss_itp/kcl_single/S2_EquilNVT/nvteql-temp.xvg'

# Load data from the specified text file into a NumPy array.
# The 'comments' parameter tells the function to ignore lines that start with these characters.
data_array = np.loadtxt(data_file, comments=('#', '@'))

# Print the shape of the array.
print("Data shape:", data_array.shape)
# Out:
# Data shape: (201, 2)

# %%
# Extract the first column as the x-axis data.
x = data_array[:, 0]

# Extract the second column as the y-axis data.
y = data_array[:, 1]

# Create a figure for the plot with a specific size.
plt.figure(figsize=(10, 6))

# Plot the x and y data.
plt.plot(x, y, label='Temperature', color='green')

# Add labels for the x and y axes.
plt.xlabel("Time (ps)")
plt.ylabel("Temperature (K)")

# Add a title to the plot.
# plt.title("GROMACS Energies")

# Display the legend.
plt.legend()

# Display the plot.
plt.show()

# %% [markdown]
# ### Pressure

# %%
# Set the file path to the Excel file containing the stress-strain data.
data_file = r'Z:/UW_Madison_Jiahui/projects/PA_Membrane/mem_moy/subhamoy_swiss_itp/nacl_0.6Molar/S2_EquilNPT/npteql-pres.xvg'

# Load data from the specified text file into a NumPy array.
# The 'comments' parameter tells the function to ignore lines that start with these characters.
data_array = np.loadtxt(data_file, comments=('#', '@'))

# Print the shape of the array.
print("Data shape:", data_array.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 6
#       2 data_file = r'Z:/UW_Madison_Jiahui/projects/PA_Membrane/mem_moy/subhamoy_swiss_itp/nacl_0.6Molar/S2_EquilNPT/npteql-pres.xvg'
#       4 # Load data from the specified text file into a NumPy array.
#       5 # The 'comments' parameter tells the function to ignore lines that start with these characters.
# ----> 6 data_array = np.loadtxt(data_file, comments=('#', '@'))
#       8 # Print the shape of the array.
#       9 print("Data shape:", data_array.shape)
#
# File d:\anaconda3\Lib\site-packages\numpy\lib\npyio.py:1338, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1335 if isinstance(delimiter, bytes):
#    1336     delimiter = delimiter.decode('latin1')
# ...

# %%
# Extract the first column as the x-axis data.
x = data_array[:, 0]

# Extract the second column as the y-axis data.
y = data_array[:, 1]

# Create a figure for the plot with a specific size.
plt.figure(figsize=(10, 6))

# Plot the x and y data.
plt.plot(x, y, label='Pressure', color='green')

# Add labels for the x and y axes.
plt.xlabel("Time (ps)")
plt.ylabel("Pressure (K)")

# Add a title to the plot.
# plt.title("GROMACS Energies")

# Display the legend.
plt.legend()

# Display the plot.
plt.show()
